# %% [markdown]
# # Proyecto Git y Github, Luis Valverde Ramirez

# %% [markdown]
# ## Seccion 1: Inicio haciendo la importacion

# %%
#Importar csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Credit.csv")

# %% [markdown]
# ## Seccion 2: mejoras en los datos

# %%
#Ver datos del dataFrame
df.info()
df.describe().round(1)

# %% [markdown]
# ## Seccion 3 Grafico

# %%
#Grafico de categorias
df.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# # Año: 2026
# # Usuario Github: LVR06
